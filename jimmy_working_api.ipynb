# %%
import hvplot.pandas
import pandas as pd
import requests
import json
import numpy as np
import matplotlib.pyplot as plt

# Import API key
from geoapify import geoapify_key

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
csv_path = 'data/VPA_Open_Space.csv'

read_csv = pd.read_csv(csv_path)

information_df = pd.DataFrame(read_csv)

information_df.sample(5)
# Out:
#          FID         LGA   VM_PARCEL_ VM_PARCE_1     DATA_SOURC  \
# 13046  13047     WYNDHAM   1\PS416524   52612239          DEECD
# 37589  37590   FRANKSTON  3A~9\PP5301   52477606  VM CL Parcels
# 18541  18542  WHITTLESEA   1\TP907768    2024052     VM Parcels
# 17630  17631  WHITTLESEA   2\PS604290  220265014     VM Parcels
# 21006  21007    MORELAND   67\LP10503   52821078     VM Parcels
#
#                                   OS_CATEGOR      OS_CATEG_2  \
# 13046                 Non-government schools  Not applicable
# 37589  Sportsfields and organised recreation  Not applicable
# 18541    Natural and semi-natural open space  Not applicable
# 17630                      Parks and gardens  Not applicable
# 21006    Natural and semi-natural open space      Local link
#
#              OWNER_TYPE                      PARK_NAME OS_STATUS  ...  \
# 13046           Private   Thomas Carr Catholic College  Existing  ...
# 37589             Crown                  Victoria Park  Existing  ...
# 18541  Local government  W.A. Smith Recreation Reserve  Existing  ...
# 17630  Local government                                 Existing  ...
# 21006           NO DATA                        NO DATA  Existing  ...
#
#        VEAC_ID WATER_BODY             OS_TYPE COASTAL MANAGER_NA  \
# 13046                      Private open space            NO DATA
# 37589  P363008              Public open space            NO DATA
# 18541  M016886              Public open space            NO DATA
# 17630                       Public open space            NO DATA
# 21006  M011112              Public open space            NO DATA
#
#                     OWNER_NAME  \
# 13046                  NO DATA
# 37589                    Crown
# 18541  Whittlesea City Council
# 17630  Whittlesea City Council
# 21006                  NO DATA
#
#                                                Image_URL VPA_ID SHAPE_Length  \
# 13046  https://lh3.googleusercontent.com/-uz6koGrYKZE...  14215     0.013788
# 37589  https://lh3.googleusercontent.com/-IeXcYfXdodo...  38046     0.006057
# 18541  https://lh3.googleusercontent.com/-mCSb2HRxCUs...  19362     0.001402
# 17630  https://lh3.googleusercontent.com/-rdTUgqfNyXg...  18282     0.007243
# 21006  https://lh3.googleusercontent.com/-mCSb2HRxCUs...  22001     0.001163
#
#          SHAPE_Area
# 13046  1.018816e-05
# 37589  2.132036e-06
# 18541  5.494702e-08
# 17630  2.739909e-06
# 21006  6.939144e-08
#
# [5 rows x 24 columns]

# %%
information_df_parks_df = information_df.loc[(information_df['OS_TYPE'] == 'Public open space')]
information_df_parks_df.sample(5)
# Out:
#          FID         LGA     VM_PARCEL_ VM_PARCE_1        DATA_SOURC  \
# 9         10  BOROONDARA     266\LP5481  203971950        VM Parcels
# 30159  30160  MORNINGTON     1\PS413576   52538576  Mornington shire
# 30146  30147  MORNINGTON   RES3\LP30065    2022398  Mornington shire
# 10579  10580      MELTON  RES2\PS602795  208251520        VM Parcels
# 13721  13722     WYNDHAM   RES1\LP91620    1792276         ARCUE2002
#
#                                   OS_CATEGOR      OS_CATEG_2  \
# 9      Sportsfields and organised recreation  Not applicable
# 30159    Natural and semi-natural open space  Not applicable
# 30146    Natural and semi-natural open space  Not applicable
# 10579                      Parks and gardens  Not applicable
# 13721                    Recreation corridor      Local link
#
#              OWNER_TYPE                           PARK_NAME OS_STATUS  ...  \
# 9      Local government                 Jack Otoole Reserve  Existing  ...
# 30159  Local government    Hilltop Ave Blairgowrie bushland  Existing  ...
# 30146  Local government    Phillipa St Blairgowrie bushland  Existing  ...
# 10579  Local government            Glencarpel Court Reserve  Existing  ...
# 13721  Local government  Marlborough Willmott Drive Walkway  Existing  ...
#
#        VEAC_ID WATER_BODY            OS_TYPE COASTAL  \
# 9                          Public open space
# 30159  M033142             Public open space
# 30146  M033047             Public open space
# 10579  M018363             Public open space
# 13721  M018768             Public open space
#
#                      MANAGER_NA                  OWNER_NAME  \
# 9                       NO DATA     Boroondara City Council
# 30159                   NO DATA  Mornington Peninsula Shire
# 30146  Mornington Shire Council  Mornington Peninsula Shire
# 10579                   NO DATA         Melton City Council
# 13721                   NO DATA        Wyndham City Council
#
#                                                Image_URL VPA_ID SHAPE_Length  \
# 9      https://lh3.googleusercontent.com/-IeXcYfXdodo...   1509     0.001683
# 30159  https://lh3.googleusercontent.com/-mCSb2HRxCUs...  31248     0.001171
# 30146  https://lh3.googleusercontent.com/-mCSb2HRxCUs...  31246     0.001091
# 10579  https://lh3.googleusercontent.com/-rdTUgqfNyXg...  11295     0.001590
# 13721  https://lh3.googleusercontent.com/-YzyOGz7u_dk...  14104     0.001630
#
#          SHAPE_Area
# 9      1.389664e-07
# 30159  6.668642e-08
# 30146  6.318599e-08
# 10579  1.459564e-07
# 13721  1.129566e-07
#
# [5 rows x 24 columns]

# %%
lga_list = pd.DataFrame(information_df_parks_df.groupby('LGA')['PARK_NAME'].count().sort_values(ascending = False).index)

lga_bucket = []

for i in range(len(lga_list)):
    lga_bucket.append(str(lga_list['LGA'][i].title()))

lga_park_count = pd.DataFrame(information_df_parks_df.groupby('LGA')['PARK_NAME'].count().sort_values(ascending = False))

lga_park_count = lga_park_count['PARK_NAME'].reset_index('LGA')

park_count = []

for i in range(len(lga_park_count)):
    park_count.append(int(lga_park_count['PARK_NAME'][i]))

# %%
lga_park_count_df = pd.DataFrame({"Local Government Area" : lga_bucket, 
                                  "Public Open Spaces" : park_count})

# %%
column_names = ['LGA code', 'Local Government Area', '2021 Population', '2022 Population', '% Population Change 21-22', 'Area (km2)', 'Population Density (persons/km2)'
            ]

lga_information_path = pd.read_excel('data/LGA_ABS_data_21_22.xlsx', 
                                     sheet_name = 2, 
                                     header = 7,
                                     names = column_names,
                                     usecols = 'A,B,C,D,G,M,N',
                                     skiprows = 1,
                                     na_values = 0)

lga_information = pd.DataFrame(lga_information_path)

lga_information.sample(30)
# Out:
#                                 LGA code Local Government Area  \
# 71                                 26890          West Wimmera
# 36                                 23810        Latrobe (Vic.)
# 58                                 25900          Port Phillip
# 16                                 21830           Corangamite
# 26                                 22750       Greater Geelong
# 33                                 23350                Indigo
# 55                                 25620           Murrindindi
# 52                                 25340  Mornington Peninsula
# 23                                 22490         Golden Plains
# 31                                 23190               Horsham
# 9                                  21180              Brimbank
# 51                                 25250              Moreland
# 84                                   NaN                   NaN
# 79                                   NaN                   NaN
# 22                                 22410               Glenelg
# 34                                 23430       Kingston (Vic.)
# 32                                 23270                  Hume
# 12                                 21450              Cardinia
# 59                                 25990              Pyrenees
# 80                                 29399    Unincorporated Vic
# 63                                 26350           Stonnington
# 45                                 24780               Mildura
# 56                                 25710             Nillumbik
# 67                                 26670                Towong
# 13                                 21610                 Casey
# 2                                  20570              Ballarat
# 73                                 27070            Whittlesea
# 85  Source: Regional population, 2021-22                   NaN
# 15                                 21750           Colac Otway
# 46                                 24850              Mitchell
#
#     2021 Population  2022 Population  % Population Change 21-22  Area (km2)  \
# 71           3978.0           3942.0                       -0.9      9108.7
# 36          77117.0          77668.0                        0.7      1425.6
# 58         103438.0         103990.0                        0.5        20.6
# 16          16030.0          15993.0                       -0.2      4407.5
# 26         270932.0         276446.0                        2.0      1248.0
# 33          17251.0          17418.0                        1.0      2040.5
# 55          15139.0          15348.0                        1.4      3879.8
# 52         170440.0         169663.0                       -0.5       724.0
# 23          24892.0          25312.0                        1.7      2703.4
# 31          20376.0          20337.0                       -0.2      4266.8
# 9          196631.0         193256.0                       -1.7       123.4
# 51         173500.0         174735.0                        0.7        51.0
# 84              NaN              NaN                        NaN         NaN
# 79              NaN              NaN                        NaN         NaN
# 22          20058.0          20041.0                       -0.1      6218.8
# 34         159554.0         160005.0                        0.3        91.4
# 32         246920.0         252987.0                        2.5       503.8
# 12         119573.0         123104.0                        3.0      1282.6
# 59           7619.0           7651.0                        0.4      3434.6
# 80            946.0            961.0                        1.6       283.2
# 63         106190.0         106418.0                        0.2        25.7
# 45          56966.0          57216.0                        0.4     22081.9
# 56          63450.0          63041.0                       -0.6       432.3
# 67           6186.0           6196.0                        0.2      6675.2
# 13         369558.0         378831.0                        2.5       409.4
# 2          113504.0         115951.0                        2.2       739.0
# 73         231831.0         236966.0                        2.2       489.7
# 85              NaN              NaN                        NaN         NaN
# 15          22309.0          22188.0                       -0.5      3437.5
# 46          49712.0          51654.0                        3.9      2862.1
#
#     Population Density (persons/km2)
# 71                               0.4
# 36                              54.5
# 58                            5044.6
# 16                               3.6
# 26                             221.5
# 33                               8.5
# 55                               4.0
# 52                             234.3
# 23                               9.4
# 31                               4.8
# 9                             1566.1
# 51                            3429.4
# 84                               NaN
# 79                               NaN
# 22                               3.2
# 34                            1751.2
# 32                             502.1
# 12                              96.0
# 59                               2.2
# 80                               3.4
# 63                            4148.7
# 45                               2.6
# 56                             145.8
# 67                               0.9
# 13                             925.3
# 2                              156.9
# 73                             483.9
# 85                               NaN
# 15                               6.5
# 46                              18.0

# %%
columns_to_check = ['LGA code', 'Local Government Area']
lga_information_cleaned = lga_information.dropna(subset= columns_to_check, how = 'any')

# %%
x_axis = np.arange(len(lga_bucket))

plt.bar(x_axis, park_count, color="royalblue", align="center", width = 0.6)
tick_locations = [value for value in x_axis]
tick_locations
plt.xticks(tick_locations, lga_bucket, rotation = 90)
plt.xlabel('LGAs')
plt.ylabel('# of Parks Per LGA')
plt.title('Public parks and Gardens in each LGA')

plt.show()

# %%
columns_to_check = ['LGA code', 'Local Government Area']
lga_information_cleaned = lga_information.dropna(subset= columns_to_check, how = 'any')

# %%
lga_filtered = lga_information_cleaned.loc[lga_information_cleaned['Local Government Area'].isin(lga_bucket)]
lga_filtered = lga_filtered.reset_index(drop = True)

# %%
merged_vic_data_df = pd.merge(lga_filtered, lga_park_count_df, how = 'inner', on = 'Local Government Area')
merged_vic_data_df.to_csv('data/merged_vic_data.csv')

# %%
merged_vic_data_df.head()
# Out:
#   LGA code Local Government Area  2021 Population  2022 Population  \
# 0    20660               Banyule         127370.0         127348.0
# 1    21110            Boroondara         169789.0         169500.0
# 2    21180              Brimbank         196631.0         193256.0
# 3    21450              Cardinia         119573.0         123104.0
# 4    21610                 Casey         369558.0         378831.0
#
#    % Population Change 21-22  Area (km2)  Population Density (persons/km2)  \
# 0                        NaN        62.5                            2036.3
# 1                       -0.2        60.2                            2816.7
# 2                       -1.7       123.4                            1566.1
# 3                        3.0      1282.6                              96.0
# 4                        2.5       409.4                             925.3
#
#    Public Open Spaces
# 0                 625
# 1                 576
# 2                 986
# 3                1287
# 4                1853

# %%
merged_vic_data_df.sort_values(by = ['Public Open Spaces'] ,ascending = False)
# Out:
#    LGA code Local Government Area  2021 Population  2022 Population  \
# 28    27450          Yarra Ranges         157421.0         157388.0
# 4     21610                 Casey         369558.0         378831.0
# 10    23270                  Hume         246920.0         252987.0
# 25    27070            Whittlesea         231831.0         236966.0
# 3     21450              Cardinia         119573.0         123104.0
# 6     22170             Frankston         140824.0         141078.0
# 26    27260               Wyndham         296322.0         309125.0
# 16    24650                Melton         181346.0         193155.0
# 21    25710             Nillumbik          63450.0          63041.0
# 2     21180              Brimbank         196631.0         193256.0
# 11    23670                  Knox         160481.0         159465.0
# 24    26980            Whitehorse         171077.0         172466.0
# 20    25250              Moreland         173500.0         174735.0
# 12    24210            Manningham         125821.0         126491.0
# 14    24410             Maroondah         116075.0         115689.0
# 8     22670     Greater Dandenong         160100.0         159151.0
# 0     20660               Banyule         127370.0         127348.0
# 1     21110            Boroondara         169789.0         169500.0
# 15    24600             Melbourne         153110.0         159993.0
# 18    24970                Monash         192893.0         194877.0
# 19    25060         Moonee Valley         122950.0         123038.0
# 5     21890               Darebin         150296.0         150483.0
# 9     23110           Hobsons Bay          92267.0          91803.0
# 13    24330           Maribyrnong          86385.0          87526.0
# 22    25900          Port Phillip         103438.0         103990.0
# 27    27350                 Yarra          91521.0          92301.0
# 23    26350           Stonnington         106190.0         106418.0
# 7     22310             Glen Eira         150638.0         151694.0
# 17    24850              Mitchell          49712.0          51654.0
#
#     % Population Change 21-22  Area (km2)  Population Density (persons/km2)  \
# 28                        NaN      2468.2                              63.8
# 4                         2.5       409.4                             925.3
# 10                        2.5       503.8                             502.1
# 25                        2.2       489.7                             483.9
# 3                         3.0      1282.6                              96.0
# 6                         0.2       129.6                            1088.6
# 26                        4.3       542.1                             570.2
# 16                        6.5       527.5                             366.1
# 21                       -0.6       432.3                             145.8
# 2                        -1.7       123.4                            1566.1
# 11                       -0.6       113.9                            1399.9
# 24                        0.8        64.3                            2683.0
# 20                        0.7        51.0                            3429.4
# 12                        0.5       113.3                            1116.0
# 14                       -0.3        61.4                            1883.9
# 8                        -0.6       129.5                            1228.5
# 0                         NaN        62.5                            2036.3
# 1                        -0.2        60.2                            2816.7
# 15                        4.5        37.5                            4261.3
# 18                        1.0        81.5                            2391.6
# 19                        0.1        43.1                            2852.2
# 5                         0.1        53.5                            2814.3
# 9                        -0.5        64.2                            1429.1
# 13                        1.3        31.2                            2803.0
# 22                        0.5        20.6                            5044.6
# 27                        0.9        19.5                            4723.2
# 23                        0.2        25.7                            4148.7
# 7                         0.7        38.7                            3920.7
# 17                        3.9      2862.1                              18.0
#
#     Public Open Spaces
# 28                2376
# 4                 1853
# 10                1333
# 25                1316
# 3                 1287
# 6                 1166
# 26                1056
# 16                1055
# 21                1007
# 2                  986
# 11                 862
# 24                 811
# 20                 809
# 12                 736
# 14                 660
# 8                  626
# 0                  625
# 1                  576
# 15                 549
# 18                 549
# 19                 526
# 5                  513
# 9                  422
# 13                 307
# 22                 295
# 27                 275
# 23                 214
# 7                  160
# 17                  80

# %%
Location_merged_map_ploting = merged_vic_data_df

# %%
# Add columns the airports data we will fetch using the Geoapify API
# Note that we used "" to specify initial entry.
Location_merged_map_ploting["Lat"] = ""
Location_merged_map_ploting["Lon"] = ""

Location_merged_map_ploting.head()
# Out:
#   LGA code Local Government Area  2021 Population  2022 Population  \
# 0    20660               Banyule         127370.0         127348.0
# 1    21110            Boroondara         169789.0         169500.0
# 2    21180              Brimbank         196631.0         193256.0
# 3    21450              Cardinia         119573.0         123104.0
# 4    21610                 Casey         369558.0         378831.0
#
#    % Population Change 21-22  Area (km2)  Population Density (persons/km2)  \
# 0                        NaN        62.5                            2036.3
# 1                       -0.2        60.2                            2816.7
# 2                       -1.7       123.4                            1566.1
# 3                        3.0      1282.6                              96.0
# 4                        2.5       409.4                             925.3
#
#    Public Open Spaces Lat Lon
# 0                 625
# 1                 576
# 2                 986
# 3                1287
# 4                1853

# %%
# Define the API parameters
params = {
    "apiKey":geoapify_key,
    "format":"json"
}

# Set the base URL
base_url = "https://api.geoapify.com/v1/geocode/search"

# %%
# Loop through the cities_pd DataFrame and search coordinates for each city
for index, row in Location_merged_map_ploting.iterrows():

    # Get the city's name & add ", Australia" to the string so geoapify finds the correct city
    city = row["Local Government Area"] + ", Victoria,Australia"

    # Add the current city to the parameters
    params["text"] = f"{city}"

    # Make the API request
    response = requests.get(base_url, params=params)
    
    # Convert reponse to JSON
    response = response.json()

    # Extract latitude and longitude
    Location_merged_map_ploting.loc[index, "Lat"] = response["results"][0]["lat"]
    Location_merged_map_ploting.loc[index, "Lon"] = response["results"][0]["lon"]
    
    # Log the search results
    print(f"Coordinates for {city} fetched...")

# Display sample data to confirm that the coordinates appear
Location_merged_map_ploting.sample(20)
# Out:
# Coordinates for Banyule, Victoria,Australia fetched...
# Coordinates for Boroondara, Victoria,Australia fetched...
# Coordinates for Brimbank, Victoria,Australia fetched...
# Coordinates for Cardinia, Victoria,Australia fetched...
# Coordinates for Casey, Victoria,Australia fetched...
# Coordinates for Darebin, Victoria,Australia fetched...
# Coordinates for Frankston, Victoria,Australia fetched...
# Coordinates for Glen Eira, Victoria,Australia fetched...
# Coordinates for Greater Dandenong, Victoria,Australia fetched...
# Coordinates for Hobsons Bay, Victoria,Australia fetched...
# Coordinates for Hume, Victoria,Australia fetched...
# Coordinates for Knox, Victoria,Australia fetched...
# Coordinates for Manningham, Victoria,Australia fetched...
# Coordinates for Maribyrnong, Victoria,Australia fetched...
# Coordinates for Maroondah, Victoria,Australia fetched...
# Coordinates for Melbourne, Victoria,Australia fetched...
# Coordinates for Melton, Victoria,Australia fetched...
# Coordinates for Mitchell, Victoria,Australia fetched...
# Coordinates for Monash, Victoria,Australia fetched...
# Coordinates for Moonee Valley, Victoria,Australia fetched...
# Coordinates for Moreland, Victoria,Australia fetched...
# Coordinates for Nillumbik, Victoria,Australia fetched...
# Coordinates for Port Phillip, Victoria,Australia fetched...
# Coordinates for Stonnington, Victoria,Australia fetched...
# Coordinates for Whitehorse, Victoria,Australia fetched...
# Coordinates for Whittlesea, Victoria,Australia fetched...
# Coordinates for Wyndham, Victoria,Australia fetched...
# Coordinates for Yarra, Victoria,Australia fetched...
# Coordinates for Yarra Ranges, Victoria,Australia fetched...
#    LGA code Local Government Area  2021 Population  2022 Population  \
# 2     21180              Brimbank         196631.0         193256.0
# 11    23670                  Knox         160481.0         159465.0
# 7     22310             Glen Eira         150638.0         151694.0
# 16    24650                Melton         181346.0         193155.0
# 13    24330           Maribyrnong          86385.0          87526.0
# 12    24210            Manningham         125821.0         126491.0
# 17    24850              Mitchell          49712.0          51654.0
# 19    25060         Moonee Valley         122950.0         123038.0
# 8     22670     Greater Dandenong         160100.0         159151.0
# 27    27350                 Yarra          91521.0          92301.0
# 15    24600             Melbourne         153110.0         159993.0
# 20    25250              Moreland         173500.0         174735.0
# 6     22170             Frankston         140824.0         141078.0
# 21    25710             Nillumbik          63450.0          63041.0
# 9     23110           Hobsons Bay          92267.0          91803.0
# 25    27070            Whittlesea         231831.0         236966.0
# 14    24410             Maroondah         116075.0         115689.0
# 18    24970                Monash         192893.0         194877.0
# 0     20660               Banyule         127370.0         127348.0
# 24    26980            Whitehorse         171077.0         172466.0
#
#     % Population Change 21-22  Area (km2)  Population Density (persons/km2)  \
# 2                        -1.7       123.4                            1566.1
# 11                       -0.6       113.9                            1399.9
# 7                         0.7        38.7                            3920.7
# 16                        6.5       527.5                             366.1
# 13                        1.3        31.2                            2803.0
# 12                        0.5       113.3                            1116.0
# 17                        3.9      2862.1                              18.0
# 19                        0.1        43.1                            2852.2
# 8                        -0.6       129.5                            1228.5
# 27                        0.9        19.5                            4723.2
# 15                        4.5        37.5                            4261.3
# 20                        0.7        51.0                            3429.4
# 6                         0.2       129.6                            1088.6
# 21                       -0.6       432.3                             145.8
# 9                        -0.5        64.2                            1429.1
# 25                        2.2       489.7                             483.9
# 14                       -0.3        61.4                            1883.9
# 18                        1.0        81.5                            2391.6
# 0                         NaN        62.5                            2036.3
# 24                        0.8        64.3                            2683.0
#
#     Public Open Spaces        Lat         Lon
# 2                  986 -37.742717  144.805427
# 11                 862 -37.898453  145.264856
# 7                  160  -37.89914  145.041033
# 16                1055 -37.683571  144.582845
# 13                 307 -37.769514  144.890205
# 12                 736 -37.757136  145.185245
# 17                  80 -37.175751  144.976528
# 19                 526 -37.749434  144.886887
# 8                  626 -38.001215  145.187055
# 27                 275 -37.804851  144.986615
# 15                 549 -37.814245  144.963173
# 20                 809 -37.725378  144.952381
# 6                 1166 -38.144473  145.126881
# 21                1007 -37.614778  145.246292
# 9                  422 -37.853383  144.923322
# 25                1316  -37.51213  145.117732
# 14                 660 -37.804655  145.261161
# 18                 549 -37.896725  145.141209
# 0                  625 -37.734063  145.086652
# 24                 811   -37.8288  145.156413

# %%
# Configure the map
map_plot_2 = Location_merged_map_ploting.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    tiles = "EsriImagery",
    frame_width = 800,
    frame_height = 600,
    size = "Population Density (persons/km2)",
    scale = 0.5,
    color = "Local Government Area"
)

# Display the map plot
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (Local Government Area,Population Density (persons/km2))
