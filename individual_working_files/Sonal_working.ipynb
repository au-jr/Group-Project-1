# %%
import pandas as pd
import requests
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
# Open_Spaces csv import

csv_path = 'data/VPA_Open_Space.csv'
read_csv = pd.read_csv(csv_path)
information_df = pd.DataFrame(read_csv)

# %%
# Filter for public open spaces
information_df_parks_df = information_df.loc[(information_df['OS_TYPE'] == 'Public open space')]

# %%
# Create a bucket and loop through all the LGA names in the dataframe and store them
lga_list = pd.DataFrame(information_df_parks_df.groupby('LGA')['PARK_NAME'].count().sort_values(ascending = False).index)
lga_list

lga_bucket = []

for i in range(len(lga_list)):
    lga_bucket.append(str(lga_list['LGA'][i].title()))

# %%
# Create a bucket and loop through all the park counts in the dataframe and store them
lga_park_count = pd.DataFrame(information_df_parks_df.groupby('LGA')['PARK_NAME'].count().sort_values(ascending = False))
lga_park_count = lga_park_count['PARK_NAME'].reset_index('LGA')
lga_park_count

park_count = []

for i in range(len(lga_park_count)):
    park_count.append(int(lga_park_count['PARK_NAME'][i]))

# %%
# Quick representation as a bar chart to visualise the number of open spaces per LGA

x_axis = np.arange(len(lga_bucket))

plt.bar(x_axis, park_count, color="royalblue", align="center", width = 0.6)
tick_locations = [value for value in x_axis]
tick_locations
plt.xticks(tick_locations, lga_bucket, rotation = 90)
plt.xlabel('LGAs')
plt.ylabel('# of Parks Per LGA')
plt.title('Public parks and Gardens in each LGA')

plt.show()

# %%
# Create a DataFrame to hold both sets of information, LGA & Open Space counts & sort them alphabetically.
lga_park_count_df = pd.DataFrame({"Local Government Area" : lga_bucket, 
                                  "Public Open Spaces" : park_count})

lga_park_count_df.sort_values(by = 'Local Government Area', ascending = True)
# Out:
#    Local Government Area  Public Open Spaces
# 18               Banyule                 625
# 30               Bayside                 131
# 19            Boroondara                 576
# 10              Brimbank                 986
# 5               Cardinia                1287
# 1                  Casey                1853
# 23               Darebin                 513
# 6              Frankston                1166
# 29             Glen Eira                 160
# 17     Greater Dandenong                 626
# 24           Hobsons Bay                 422
# 3                   Hume                1333
# 15              Kingston                 690
# 11                  Knox                 862
# 14            Manningham                 736
# 25           Maribyrnong                 307
# 16             Maroondah                 660
# 20             Melbourne                 549
# 8                 Melton                1055
# 31              Mitchell                  80
# 21                Monash                 549
# 22         Moonee Valley                 526
# 13              Moreland                 809
# 2             Mornington                1819
# 9              Nillumbik                1007
# 26          Port Phillip                 295
# 28           Stonnington                 214
# 12            Whitehorse                 811
# 4             Whittlesea                1316
# 7                Wyndham                1056
# 27                 Yarra                 275
# 0           Yarra Ranges                2376

# %%
# Create a list of columns names to use when importing the next file
column_names = ['LGA code', 'Local Government Area', '2021 Population', 
                '2022 Population', 'Population Change 21-22', '% Change 21-22', 'Area (km2)', 
                'Population Density (persons/km2)'
            ]

# %%
# Import the excel file and use the column_names bucket to use as the column names.
lga_information_path = pd.read_excel('data/LGA_ABS_data_21_22.xlsx', 
                                     sheet_name = 2, 
                                     header = 7,
                                     names = column_names,
                                     usecols = 'A,B,C,D,F,G,M,N',
                                     skiprows = 1,
                                     na_values = 0)
lga_information = pd.DataFrame(lga_information_path)
lga_information
# Out:
#                                 LGA code Local Government Area  \
# 0                                  20110                Alpine
# 1                                  20260                Ararat
# 2                                  20570              Ballarat
# 3                                  20660               Banyule
# 4                                  20740            Bass Coast
# ..                                   ...                   ...
# 83                                   NaN                   NaN
# 84                                   NaN                   NaN
# 85  Source: Regional population, 2021-22                   NaN
# 86                                   NaN                   NaN
# 87      © Commonwealth of Australia 2023                   NaN
#
#     2021 Population  2022 Population  Population Change 21-22  % Change 21-22  \
# 0           13166.0          13187.0                     21.0             0.2
# 1           11827.0          11754.0                    -73.0            -0.6
# 2          113504.0         115951.0                   2447.0             2.2
# 3          127370.0         127348.0                    -22.0             NaN
# 4           40675.0          41798.0                   1123.0             2.8
# ..              ...              ...                      ...             ...
# 83              NaN              NaN                      NaN             NaN
# 84              NaN              NaN                      NaN             NaN
# 85              NaN              NaN                      NaN             NaN
# 86              NaN              NaN                      NaN             NaN
# 87              NaN              NaN                      NaN             NaN
#
#     Area (km2)  Population Density (persons/km2)
# 0       4788.2                               2.8
# 1       4211.1                               2.8
# 2        739.0                             156.9
# 3         62.5                            2036.3
# 4        865.8                              48.3
# ..         ...                               ...
# 83         NaN                               NaN
# 84         NaN                               NaN
# 85         NaN                               NaN
# 86         NaN                               NaN
# 87         NaN                               NaN
#
# [88 rows x 8 columns]

# %%
# Any NaN values in the population change % replaced by zeroes

work_bucket = []
change_search = range(len(lga_information['% Change 21-22']))

for i in change_search:
    
    work_bucket.append(lga_information['% Change 21-22'][i])

work_bucket = pd.Series(work_bucket, dtype=object).fillna(0).tolist()

lga_information['% Change 21-22'] = work_bucket

# %%
lga_information
# Out:
#                                 LGA code Local Government Area  \
# 0                                  20110                Alpine
# 1                                  20260                Ararat
# 2                                  20570              Ballarat
# 3                                  20660               Banyule
# 4                                  20740            Bass Coast
# ..                                   ...                   ...
# 83                                   NaN                   NaN
# 84                                   NaN                   NaN
# 85  Source: Regional population, 2021-22                   NaN
# 86                                   NaN                   NaN
# 87      © Commonwealth of Australia 2023                   NaN
#
#     2021 Population  2022 Population  Population Change 21-22  % Change 21-22  \
# 0           13166.0          13187.0                     21.0             0.2
# 1           11827.0          11754.0                    -73.0            -0.6
# 2          113504.0         115951.0                   2447.0             2.2
# 3          127370.0         127348.0                    -22.0             0.0
# 4           40675.0          41798.0                   1123.0             2.8
# ..              ...              ...                      ...             ...
# 83              NaN              NaN                      NaN             0.0
# 84              NaN              NaN                      NaN             0.0
# 85              NaN              NaN                      NaN             0.0
# 86              NaN              NaN                      NaN             0.0
# 87              NaN              NaN                      NaN             0.0
#
#     Area (km2)  Population Density (persons/km2)
# 0       4788.2                               2.8
# 1       4211.1                               2.8
# 2        739.0                             156.9
# 3         62.5                            2036.3
# 4        865.8                              48.3
# ..         ...                               ...
# 83         NaN                               NaN
# 84         NaN                               NaN
# 85         NaN                               NaN
# 86         NaN                               NaN
# 87         NaN                               NaN
#
# [88 rows x 8 columns]

# %%
# Filter information by the LGA list we've gotten from the first dataset we've imported using the .isin
lga_filtered = lga_information.loc[lga_information['Local Government Area'].isin(lga_bucket)]
lga_filtered = lga_filtered.reset_index(drop = True)

# %%
# Merge the information into one DF using Merge on the LGA name & sort data alphabetically
merged_vic_data_df = pd.merge(lga_filtered, lga_park_count_df, how = 'inner', on = 'Local Government Area')
merged_vic_data_df.to_csv('data/merged_vic_data.csv')
merged_vic_data_df.sort_values(by = ['Local Government Area'] ,ascending = True)
# Out:
#    LGA code Local Government Area  2021 Population  2022 Population  \
# 0     20660               Banyule         127370.0         127348.0
# 1     20910               Bayside         102328.0         102177.0
# 2     21110            Boroondara         169789.0         169500.0
# 3     21180              Brimbank         196631.0         193256.0
# 4     21450              Cardinia         119573.0         123104.0
# 5     21610                 Casey         369558.0         378831.0
# 6     21890               Darebin         150296.0         150483.0
# 7     22170             Frankston         140824.0         141078.0
# 8     22310             Glen Eira         150638.0         151694.0
# 9     22670     Greater Dandenong         160100.0         159151.0
# 10    23110           Hobsons Bay          92267.0          91803.0
# 11    23270                  Hume         246920.0         252987.0
# 12    23430              Kingston         159554.0         160005.0
# 13    23670                  Knox         160481.0         159465.0
# 14    24210            Manningham         125821.0         126491.0
# 15    24330           Maribyrnong          86385.0          87526.0
# 16    24410             Maroondah         116075.0         115689.0
# 17    24600             Melbourne         153110.0         159993.0
# 18    24650                Melton         181346.0         193155.0
# 19    24850              Mitchell          49712.0          51654.0
# 20    24970                Monash         192893.0         194877.0
# 21    25060         Moonee Valley         122950.0         123038.0
# 22    25250              Moreland         173500.0         174735.0
# 23    25340            Mornington         170440.0         169663.0
# 24    25710             Nillumbik          63450.0          63041.0
# 25    25900          Port Phillip         103438.0         103990.0
# 26    26350           Stonnington         106190.0         106418.0
# 27    26980            Whitehorse         171077.0         172466.0
# 28    27070            Whittlesea         231831.0         236966.0
# 29    27260               Wyndham         296322.0         309125.0
# 30    27350                 Yarra          91521.0          92301.0
# 31    27450          Yarra Ranges         157421.0         157388.0
#
#     Population Change 21-22  % Change 21-22  Area (km2)  \
# 0                     -22.0             0.0        62.5
# 1                    -151.0            -0.1        37.2
# 2                    -289.0            -0.2        60.2
# 3                   -3375.0            -1.7       123.4
# 4                    3531.0             3.0      1282.6
# 5                    9273.0             2.5       409.4
# 6                     187.0             0.1        53.5
# 7                     254.0             0.2       129.6
# 8                    1056.0             0.7        38.7
# 9                    -949.0            -0.6       129.5
# 10                   -464.0            -0.5        64.2
# 11                   6067.0             2.5       503.8
# 12                    451.0             0.3        91.4
# 13                  -1016.0            -0.6       113.9
# 14                    670.0             0.5       113.3
# 15                   1141.0             1.3        31.2
# 16                   -386.0            -0.3        61.4
# 17                   6883.0             4.5        37.5
# 18                  11809.0             6.5       527.5
# 19                   1942.0             3.9      2862.1
# 20                   1984.0             1.0        81.5
# 21                     88.0             0.1        43.1
# 22                   1235.0             0.7        51.0
# 23                   -777.0            -0.5       724.0
# 24                   -409.0            -0.6       432.3
# 25                    552.0             0.5        20.6
# 26                    228.0             0.2        25.7
# 27                   1389.0             0.8        64.3
# 28                   5135.0             2.2       489.7
# 29                  12803.0             4.3       542.1
# 30                    780.0             0.9        19.5
# 31                    -33.0             0.0      2468.2
#
#     Population Density (persons/km2)  Public Open Spaces
# 0                             2036.3                 625
# 1                             2745.9                 131
# 2                             2816.7                 576
# 3                             1566.1                 986
# 4                               96.0                1287
# 5                              925.3                1853
# 6                             2814.3                 513
# 7                             1088.6                1166
# 8                             3920.7                 160
# 9                             1228.5                 626
# 10                            1429.1                 422
# 11                             502.1                1333
# 12                            1751.2                 690
# 13                            1399.9                 862
# 14                            1116.0                 736
# 15                            2803.0                 307
# 16                            1883.9                 660
# 17                            4261.3                 549
# 18                             366.1                1055
# 19                              18.0                  80
# 20                            2391.6                 549
# 21                            2852.2                 526
# 22                            3429.4                 809
# 23                             234.3                1819
# 24                             145.8                1007
# 25                            5044.6                 295
# 26                            4148.7                 214
# 27                            2683.0                 811
# 28                             483.9                1316
# 29                             570.2                1056
# 30                            4723.2                 275
# 31                              63.8                2376

# %%
merged_vic_data_df.head()
# Out:
#   LGA code Local Government Area  2021 Population  2022 Population  \
# 0    20660               Banyule         127370.0         127348.0
# 1    20910               Bayside         102328.0         102177.0
# 2    21110            Boroondara         169789.0         169500.0
# 3    21180              Brimbank         196631.0         193256.0
# 4    21450              Cardinia         119573.0         123104.0
#
#    Population Change 21-22  % Change 21-22  Area (km2)  \
# 0                    -22.0             0.0        62.5
# 1                   -151.0            -0.1        37.2
# 2                   -289.0            -0.2        60.2
# 3                  -3375.0            -1.7       123.4
# 4                   3531.0             3.0      1282.6
#
#    Population Density (persons/km2)  Public Open Spaces
# 0                            2036.3                 625
# 1                            2745.9                 131
# 2                            2816.7                 576
# 3                            1566.1                 986
# 4                              96.0                1287

# %%
#Plotting the bar graph
plt.figure(figsize=(10, 6))
bars = plt.bar(merged_vic_data_df['Local Government Area'], merged_vic_data_df['Public Open Spaces'], color='skyblue')
plt.xlabel('Local Government Area')
plt.ylabel('Public Open Spaces')
plt.title('Local Government Area / Public Open Spaces')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

# Displaying values on the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 0), va='bottom', ha='center')

plt.tight_layout()
plt.show()

# %%
# Imprt the school information dataset.
school_csv_path = 'data/dv309_schoollocations2021.csv'

school_read_csv = pd.read_csv(school_csv_path, encoding = 'cp1252')

school_count_df = pd.DataFrame(school_read_csv)

# %%
# Replace unwanted string characters in the LGA Name column to allow us to merge the data later

school_count_df['LGA_Name'] = school_count_df['LGA_Name'].str.replace(r" \(.*\)", "")
# Out:
# c:\Users\vaibh\anaconda3\envs\myfirstpythonenv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Filter the schools dataset by only the LGAs in the existing dataframe
school_count_df_filtered = school_count_df.loc[school_count_df['LGA_Name'].isin(merged_vic_data_df['Local Government Area'])]

# %%
# Group by the LGA and school type to get all the LGa schools information to merge with dataframe later
by_school_type_df = school_count_df_filtered.groupby(['LGA_Name', 'School_Type'])['SCHOOL_NO'].count()
school_type_df = pd.DataFrame(by_school_type_df)
school_type_df
# Out:
#                           SCHOOL_NO
# LGA_Name     School_Type
# Banyule      Pri/Sec              3
#              Primary             29
#              Secondary            8
#              Special              3
# Bayside      Pri/Sec              3
# ...                             ...
# Yarra        Special              1
# Yarra Ranges Pri/Sec              8
#              Primary             58
#              Secondary           10
#              Special              4
#
# [130 rows x 1 columns]

# %%
# Drop all the information into the table to use .loc to slice.
school_type_df = school_type_df.reset_index(inplace = False)
school_type_df
# Out:
#          LGA_Name School_Type  SCHOOL_NO
# 0         Banyule     Pri/Sec          3
# 1         Banyule     Primary         29
# 2         Banyule   Secondary          8
# 3         Banyule     Special          3
# 4         Bayside     Pri/Sec          3
# ..            ...         ...        ...
# 125         Yarra     Special          1
# 126  Yarra Ranges     Pri/Sec          8
# 127  Yarra Ranges     Primary         58
# 128  Yarra Ranges   Secondary         10
# 129  Yarra Ranges     Special          4
#
# [130 rows x 3 columns]

# %%
# Loop through to find all the different types of schools

school_range = range(len(school_type_df['School_Type'].unique()))

school_types = []

for i in school_range:
    school_types.append(school_type_df['School_Type'].unique()[i])

# %%
# for each school type create a dictionary within a list to hold the information. Can call the list by the dictionary index.
school_search_len = range(len(school_types))
dictionary_list = [{} for i in school_search_len]
dictionary_list
# Out:
# [{}, {}, {}, {}, {}]

# %%
# Loop through each school type and get the information for each LGA and append it to the list of dictionaries
school_search_len = range(len(school_types))

counter = 0

for i in school_search_len:
    search_df = school_type_df.loc[school_type_df['School_Type'] == school_types[i]].reset_index(drop = True)
    for j in range(len(search_df['LGA_Name'])):
        dictionary_list[counter][search_df['LGA_Name'][j]] = search_df['SCHOOL_NO'][j]
    counter += 1

# %%
# Define variables which hold the information for each school type

primary_secondary_counts = dictionary_list[0]
primary_counts = dictionary_list[1]
secondary_counts = dictionary_list[2]
special_counts = dictionary_list[3]
language_counts = dictionary_list[4]

# %%
# For each school type go through and make a DF of each LGA & count of school

prisec_df = pd.Series(primary_secondary_counts, name = 'Primary/Secondary Schools')
prisec_df = pd.DataFrame(prisec_df).reset_index(drop = False)
prisec_df = prisec_df.rename(columns= {'index' : 'Local Government Area'})
prisec_df['Primary/Secondary Schools'] = prisec_df['Primary/Secondary Schools'].astype(int)

# %%
# For each school type go through and make a DF of each LGA & count of school

pri_df = pd.Series(primary_counts, name = 'Primary Schools')
pri_df = pd.DataFrame(pri_df).reset_index(drop = False)
pri_df = pri_df.rename(columns= {'index' : 'Local Government Area'})
pri_df['Primary Schools'] = pri_df['Primary Schools'].astype(int)

# %%
# For each school type go through and make a DF of each LGA & count of school

sec_df = pd.Series(secondary_counts, name = 'Secondary Schools')
sec_df = pd.DataFrame(sec_df).reset_index(drop = False)
sec_df = sec_df.rename(columns= {'index' : 'Local Government Area'})
sec_df['Secondary Schools'] = sec_df['Secondary Schools'].astype(int)

# %%
# For each school type go through and make a DF of each LGA & count of school

spec_df = pd.Series(special_counts, name = 'Special Schools')
spec_df = pd.DataFrame(spec_df).reset_index(drop = False)
spec_df = spec_df.rename(columns= {'index' : 'Local Government Area'})
spec_df['Special Schools'] = spec_df['Special Schools'].astype(int)

# %%
# For each school type go through and make a DF of each LGA & count of school

lang_df = pd.Series(language_counts, name = 'Language Schools')
lang_df = pd.DataFrame(lang_df).reset_index(drop = False)
lang_df = lang_df.rename(columns= {'index' : 'Local Government Area'})
lang_df['Language Schools'] = lang_df['Language Schools'].astype(int)

# %%
# Merge the school information into the combined DF
merged_vic_data_df = pd.merge(merged_vic_data_df, prisec_df, how = 'outer', on = 'Local Government Area')
merged_vic_data_df = pd.merge(merged_vic_data_df, pri_df, how = 'outer', on = 'Local Government Area')
merged_vic_data_df = pd.merge(merged_vic_data_df, sec_df, how = 'outer', on = 'Local Government Area')
merged_vic_data_df = pd.merge(merged_vic_data_df, spec_df, how = 'outer', on = 'Local Government Area')
merged_vic_data_df = pd.merge(merged_vic_data_df, lang_df, how = 'outer', on = 'Local Government Area')

# %%
# For some reason when we triedconverting from Float to int, it rolled integer counts which were zero as the highest negative integer. This code converts the nan values into zeros without the integer rollback issue

search_columns = ['Primary/Secondary Schools', 'Primary Schools', 'Secondary Schools', 'Special Schools', 'Language Schools']

for i in search_columns:
    arr = np.array(merged_vic_data_df[i])
    arr = np.nan_to_num(arr, nan=0, posinf=None, neginf=None)  # Replace infinite values with a specific value
    arr = arr.astype(int)  # Convert to integearr
    merged_vic_data_df[i] = arr

# %%
# Get the school count totals into a list. The benefit of a list here is we can double check against the original df using .loc and .counts to slice by LGA and school type.

total_schools_bucket = {}
column_list = ['Primary/Secondary Schools', 'Primary Schools', 'Secondary Schools', 'Special Schools', 'Language Schools']
counter = 0

search_range = range(len(merged_vic_data_df['Primary/Secondary Schools']))

for i in search_range:
    tally = merged_vic_data_df['Primary/Secondary Schools'][i] + merged_vic_data_df['Primary Schools'][i] + merged_vic_data_df['Secondary Schools'][i] + merged_vic_data_df['Special Schools'][i] + merged_vic_data_df['Language Schools'][i]
    total_schools_bucket[merged_vic_data_df['Local Government Area'][i]] = tally

# Turn the dictionary into a series with LGA as the index
total_schools_bucket_series = pd.Series(total_schools_bucket, index = merged_vic_data_df['Local Government Area'])

# Turn the series' values (which is the total school counts) into a new column in the merged data frame.
merged_vic_data_df['Total Schools'] = total_schools_bucket_series.values

# %%
merged_vic_data_df.to_excel('data/Complete_Dataset.xlsx')

# %%
merged_vic_data_df
# Out:
#    LGA code Local Government Area  2021 Population  2022 Population  \
# 0     20660               Banyule         127370.0         127348.0
# 1     20910               Bayside         102328.0         102177.0
# 2     21110            Boroondara         169789.0         169500.0
# 3     21180              Brimbank         196631.0         193256.0
# 4     21450              Cardinia         119573.0         123104.0
# 5     21610                 Casey         369558.0         378831.0
# 6     21890               Darebin         150296.0         150483.0
# 7     22170             Frankston         140824.0         141078.0
# 8     22310             Glen Eira         150638.0         151694.0
# 9     22670     Greater Dandenong         160100.0         159151.0
# 10    23110           Hobsons Bay          92267.0          91803.0
# 11    23270                  Hume         246920.0         252987.0
# 12    23430              Kingston         159554.0         160005.0
# 13    23670                  Knox         160481.0         159465.0
# 14    24210            Manningham         125821.0         126491.0
# 15    24330           Maribyrnong          86385.0          87526.0
# 16    24410             Maroondah         116075.0         115689.0
# 17    24600             Melbourne         153110.0         159993.0
# 18    24650                Melton         181346.0         193155.0
# 19    24850              Mitchell          49712.0          51654.0
# 20    24970                Monash         192893.0         194877.0
# 21    25060         Moonee Valley         122950.0         123038.0
# 22    25250              Moreland         173500.0         174735.0
# 23    25340            Mornington         170440.0         169663.0
# 24    25710             Nillumbik          63450.0          63041.0
# 25    25900          Port Phillip         103438.0         103990.0
# 26    26350           Stonnington         106190.0         106418.0
# 27    26980            Whitehorse         171077.0         172466.0
# 28    27070            Whittlesea         231831.0         236966.0
# 29    27260               Wyndham         296322.0         309125.0
# 30    27350                 Yarra          91521.0          92301.0
# 31    27450          Yarra Ranges         157421.0         157388.0
#
#     Population Change 21-22  % Change 21-22  Area (km2)  \
# 0                     -22.0             0.0        62.5
# 1                    -151.0            -0.1        37.2
# 2                    -289.0            -0.2        60.2
# 3                   -3375.0            -1.7       123.4
# 4                    3531.0             3.0      1282.6
# 5                    9273.0             2.5       409.4
# 6                     187.0             0.1        53.5
# 7                     254.0             0.2       129.6
# 8                    1056.0             0.7        38.7
# 9                    -949.0            -0.6       129.5
# 10                   -464.0            -0.5        64.2
# 11                   6067.0             2.5       503.8
# 12                    451.0             0.3        91.4
# 13                  -1016.0            -0.6       113.9
# 14                    670.0             0.5       113.3
# 15                   1141.0             1.3        31.2
# 16                   -386.0            -0.3        61.4
# 17                   6883.0             4.5        37.5
# 18                  11809.0             6.5       527.5
# 19                   1942.0             3.9      2862.1
# 20                   1984.0             1.0        81.5
# 21                     88.0             0.1        43.1
# 22                   1235.0             0.7        51.0
# 23                   -777.0            -0.5       724.0
# 24                   -409.0            -0.6       432.3
# 25                    552.0             0.5        20.6
# 26                    228.0             0.2        25.7
# 27                   1389.0             0.8        64.3
# 28                   5135.0             2.2       489.7
# 29                  12803.0             4.3       542.1
# 30                    780.0             0.9        19.5
# 31                    -33.0             0.0      2468.2
#
#     Population Density (persons/km2)  Public Open Spaces  \
# 0                             2036.3                 625
# 1                             2745.9                 131
# 2                             2816.7                 576
# 3                             1566.1                 986
# 4                               96.0                1287
# 5                              925.3                1853
# 6                             2814.3                 513
# 7                             1088.6                1166
# 8                             3920.7                 160
# 9                             1228.5                 626
# 10                            1429.1                 422
# 11                             502.1                1333
# 12                            1751.2                 690
# 13                            1399.9                 862
# 14                            1116.0                 736
# 15                            2803.0                 307
# 16                            1883.9                 660
# 17                            4261.3                 549
# 18                             366.1                1055
# 19                              18.0                  80
# 20                            2391.6                 549
# 21                            2852.2                 526
# 22                            3429.4                 809
# 23                             234.3                1819
# 24                             145.8                1007
# 25                            5044.6                 295
# 26                            4148.7                 214
# 27                            2683.0                 811
# 28                             483.9                1316
# 29                             570.2                1056
# 30                            4723.2                 275
# 31                              63.8                2376
#
#     Primary/Secondary Schools  Primary Schools  Secondary Schools  \
# 0                           3               29                  8
# 1                           3               19                  5
# 2                          13               31                  9
# 3                           1               45                 10
# 4                           3               28                  6
# 5                           9               59                 13
# 6                           5               30                  7
# 7                           2               28                  8
# 8                          10               21                  6
# 9                           7               26                  7
# 10                          3               21                  3
# 11                          7               43                 10
# 12                          3               33                  7
# 13                          4               36                  6
# 14                          1               22                  6
# 15                          0               14                  4
# 16                          3               22                  7
# 17                          3                9                  8
# 18                          6               24                  7
# 19                          3               13                  3
# 20                          2               35                 13
# 21                          2               25                  8
# 22                          4               31                  7
# 23                          4               36                  7
# 24                          2               21                  3
# 25                          3               11                  5
# 26                          8               11                  3
# 27                          3               34                 10
# 28                          7               36                  9
# 29                         16               31                  9
# 30                          3               18                  7
# 31                          8               58                 10
#
#     Special Schools  Language Schools  Total Schools
# 0                 3                 0             43
# 1                 1                 0             28
# 2                 5                 0             58
# 3                 3                 0             59
# 4                 1                 0             38
# 5                 2                 0             83
# 6                 4                 0             46
# 7                 3                 0             41
# 8                 2                 0             39
# 9                 3                 1             44
# 10                2                 0             29
# 11                4                 0             64
# 12                3                 0             46
# 13                2                 0             48
# 14                2                 0             31
# 15                2                 1             21
# 16                1                 0             33
# 17                7                 0             27
# 18                1                 0             38
# 19                0                 0             19
# 20                6                 0             56
# 21                3                 0             38
# 22                2                 0             44
# 23                3                 0             50
# 24                1                 0             27
# 25                2                 0             21
# 26                2                 0             24
# 27                4                 1             52
# 28                1                 0             53
# 29                1                 0             57
# 30                1                 1             30
# 31                4                 0             80

# %%
schools_data = merged_vic_data_df[['Local Government Area', 'Primary/Secondary Schools', 'Primary Schools', 'Secondary Schools', 'Special Schools', 'Language Schools']]
schools_data
# Out:
#    Local Government Area  Primary/Secondary Schools  Primary Schools  \
# 0                Banyule                          3               29
# 1                Bayside                          3               19
# 2             Boroondara                         13               31
# 3               Brimbank                          1               45
# 4               Cardinia                          3               28
# 5                  Casey                          9               59
# 6                Darebin                          5               30
# 7              Frankston                          2               28
# 8              Glen Eira                         10               21
# 9      Greater Dandenong                          7               26
# 10           Hobsons Bay                          3               21
# 11                  Hume                          7               43
# 12              Kingston                          3               33
# 13                  Knox                          4               36
# 14            Manningham                          1               22
# 15           Maribyrnong                          0               14
# 16             Maroondah                          3               22
# 17             Melbourne                          3                9
# 18                Melton                          6               24
# 19              Mitchell                          3               13
# 20                Monash                          2               35
# 21         Moonee Valley                          2               25
# 22              Moreland                          4               31
# 23            Mornington                          4               36
# 24             Nillumbik                          2               21
# 25          Port Phillip                          3               11
# 26           Stonnington                          8               11
# 27            Whitehorse                          3               34
# 28            Whittlesea                          7               36
# 29               Wyndham                         16               31
# 30                 Yarra                          3               18
# 31          Yarra Ranges                          8               58
#
#     Secondary Schools  Special Schools  Language Schools
# 0                   8                3                 0
# 1                   5                1                 0
# 2                   9                5                 0
# 3                  10                3                 0
# 4                   6                1                 0
# 5                  13                2                 0
# 6                   7                4                 0
# 7                   8                3                 0
# 8                   6                2                 0
# 9                   7                3                 1
# 10                  3                2                 0
# 11                 10                4                 0
# 12                  7                3                 0
# 13                  6                2                 0
# 14                  6                2                 0
# 15                  4                2                 1
# 16                  7                1                 0
# 17                  8                7                 0
# 18                  7                1                 0
# 19                  3                0                 0
# 20                 13                6                 0
# 21                  8                3                 0
# 22                  7                2                 0
# 23                  7                3                 0
# 24                  3                1                 0
# 25                  5                2                 0
# 26                  3                2                 0
# 27                 10                4                 1
# 28                  9                1                 0
# 29                  9                1                 0
# 30                  7                1                 1
# 31                 10                4                 0

# %%
# plot data in stack manner of bar type
schools_data.plot(x='Local Government Area', kind='bar', stacked=True,
        title='Stacked Bar Graph by dataframe')
plt.show()

# %%
# Example data (replace with your actual data)
local_gov_areas = merged_vic_data_df['Local Government Area']
population_density = merged_vic_data_df['Total Schools']
# Assuming there's another dimension named 'Fourth Dimension'
fourth_dimension = merged_vic_data_df['Public Open Spaces']

# Define colors for the fourth dimension
colors = np.linspace(0, 1, len(fourth_dimension))  # Use a colormap to generate colors based on the fourth dimension values

# Plotting
plt.figure(figsize=(10, 7))
scatter = plt.scatter(local_gov_areas, population_density, c=fourth_dimension, cmap='viridis', s=50)
plt.colorbar(scatter, label='Fourth Dimension')  # Add color bar for the fourth dimension
plt.xlabel('Local Government Area')
plt.ylabel('Total Schools')
plt.title('Total Schools/Local Government Area /Open Spaces ')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
#Plotting the bar graph
plt.figure(figsize=(10, 7))
bars = plt.bar(merged_vic_data_df['Local Government Area'], merged_vic_data_df['Population Density (persons/km2)'], color='skyblue')
plt.xlabel('Local Government Area')
plt.ylabel('Population density')
plt.title('Local Government Area / population as of 2022')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

# Displaying values on the bars
for bar in bars:
   yval = bar.get_height()
   plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 0), va='bottom', ha='center')

plt.tight_layout()
plt.show()
